# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\Saujanya Gadge\OneDrive\Desktop\internship\INTERNSHIP PROJECTS\Cleaned_KRvideos.csv")
data.head()
# Out:
#       video_id trending_date  \
# 0  RxGQe4EeEpA    2017-11-14
# 1  hH7wVE8OlQ0    2017-11-14
# 2  9V8bnWUmE9U    2017-11-14
# 3  0_8py-t5R80    2017-11-14
# 4  bk55RbxiQdI    2017-11-14
#
#                                                title  \
# 0           ì¢ì by ë¯¼ì_ì¤ì¢
# ì _ì¢ë ëµê°
# 1                 JSA ê·ì ë¶íêµ° ì´ê²© ë¶ì
# 2  ëëª°ë¼í¨ë°ë¦¬ ì´ëí ìì 2í (ë¹¼ë...
# 3  áá
# µáá
# §á¼áá
# ¡á¨ ì¶êµ­ íì¥, ëì¹...
# 4  ê¹ì¥ê²¸ì ë¬¼ë¬ê°ë¤ MBC ë
# ¸ì¡° íí¸ì...
#
#                channel_title  category_id               publish_time  \
# 0         ë¼í¸ë§ì½ë¦¬ì           22  2017-11-13 07:07:36+00:00
# 1                     Edward           25  2017-11-13 10:59:16+00:00
# 2  ëëª°ë¼í¨ë°ë¦¬ í«ì¼           22  2017-11-11 07:16:08+00:00
# 3            ë¯¸ëì´ëª½êµ¬           25  2017-11-12 11:19:52+00:00
# 4                     NocutV           25  2017-11-13 11:08:59+00:00
#
#                                                 tags   views  likes  dislikes  \
# 0  ë¼í¸ë§|"ì¤ì¢
# ì "|"ì¢ë"|"ì¢ì"|"ì¬ë ...  156130   1422        40
# 1  JSA|"ê·ì"|"ë¶íêµ°"|"ì´ê²©"|"ë¶ì"|"JS...   76533    211        28
# 2  ìëë¤ì¤|"ë¹¼ë¹¼ë¡"|"í«ì¼"|"ëëª°ë¼í...  421409   5112       166
# 3  ì´ëª
# ë°|"ì´ëª
# ë° ì¶êµ­ê¸ì§"|"ì´ëª
# ë° ...  222850   2093       173
# 4  nocutV|"ë
# ¸ì»·V"|"CBS"|"mbc"|"ê¹ì¥ê²¸"|"í´ì...   84466   1094       109
#
#    comment_count    category_name  title_sentiment
# 0            272   People & Blogs              0.0
# 1            113  News & Politics              0.0
# 2            459   People & Blogs              0.0
# 3           1219  News & Politics              0.0
# 4            450  News & Politics              0.0

# %%
plt.figure(figsize=(12,6))
sns.countplot(y='category_name', data=data, order = data['category_name'].value_counts().index)
plt.title('Most Trending Video Categories in KR')
plt.xlabel('Number of Videos')
plt.ylabel('Category')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(data['views'], bins=50, kde=True)
plt.title('Distribution of Video Views')
plt.xlabel('Views')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(data['title_sentiment'], bins=50, kde=True, color='purple')
plt.title('Sentiment Polarity Distribution of Video Titles')
plt.xlabel('Sentiment Score')
plt.ylabel('Number of Videos')
plt.show()

# %%
plt.figure(figsize=(12,6))
data['trending_date'] = pd.to_datetime(data['trending_date'])
data.groupby('trending_date').size().plot()
plt.title('Number of Trending Videos Over Time')
plt.xlabel('Trending Date')
plt.ylabel('Number of Videos')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='views', y='likes', data=data)
plt.title('Views vs Likes')
plt.xlabel('Views')
plt.ylabel('Likes')
plt.show()

# %%
avg_views = data.groupby('category_name')['views'].mean().sort_values(ascending=False)

plt.figure(figsize=(12,6))
sns.barplot(x=avg_views.values, y=avg_views.index)
plt.title('Average Views per Video Category')
plt.xlabel('Average Views')
plt.ylabel('Category')
plt.show()
