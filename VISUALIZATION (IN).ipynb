# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\Saujanya Gadge\OneDrive\Desktop\internship\INTERNSHIP PROJECTS\Cleaned_INvideos.csv")
data.head()
# Out:
#       video_id trending_date  \
# 0  kzwfHumJyYc    2017-11-14
# 1  zUZ1z7FwLc8    2017-11-14
# 2  10L1hZ9qa58    2017-11-14
# 3  N1vE8iiEg64    2017-11-14
# 4  kJzGH0PVQHQ    2017-11-14
#
#                                                title    channel_title  \
# 0  Sharry Mann: Cute Munda ( Song Teaser) | Parmi...  Lokdhun Punjabi
# 1  पीरियड्स के समय, पेट पर पति करता ऐसा, देखकर दं...          HJ NEWS
# 2  Stylish Star Allu Arjun @ ChaySam Wedding Rece...             TFPC
# 3                     Eruma Saani | Tamil vs English      Eruma Saani
# 4  why Samantha became EMOTIONAL @ Samantha naga ...       Filmylooks
#
#    category_id               publish_time  \
# 0            1  2017-11-12 12:20:39+00:00
# 1           25  2017-11-13 05:43:56+00:00
# 2           24  2017-11-12 15:48:08+00:00
# 3           23  2017-11-12 07:08:48+00:00
# 4           24  2017-11-13 01:14:16+00:00
#
#                                                 tags    views  likes  \
# ...

# %%
plt.figure(figsize=(12,6))
sns.countplot(y='category_name', data=data, order = data['category_name'].value_counts().index)
plt.title('Most Trending Video Categories in India')
plt.xlabel('Number of Videos')
plt.ylabel('Category')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(data['views'], bins=50, kde=True)
plt.title('Distribution of Video Views')
plt.xlabel('Views')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(data['title_sentiment'], bins=50, kde=True, color='purple')
plt.title('Sentiment Polarity Distribution of Video Titles')
plt.xlabel('Sentiment Score')
plt.ylabel('Number of Videos')
plt.show()

# %%
plt.figure(figsize=(12,6))
data['trending_date'] = pd.to_datetime(data['trending_date'])
data.groupby('trending_date').size().plot()
plt.title('Number of Trending Videos Over Time')
plt.xlabel('Trending Date')
plt.ylabel('Number of Videos')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='views', y='likes', data=data)
plt.title('Views vs Likes')
plt.xlabel('Views')
plt.ylabel('Likes')
plt.show()

# %%
avg_views = data.groupby('category_name')['views'].mean().sort_values(ascending=False)

plt.figure(figsize=(12,6))
sns.barplot(x=avg_views.values, y=avg_views.index)
plt.title('Average Views per Video Category')
plt.xlabel('Average Views')
plt.ylabel('Category')
plt.show()
