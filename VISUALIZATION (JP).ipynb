# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\Saujanya Gadge\OneDrive\Desktop\internship\INTERNSHIP PROJECTS\Cleaned_JPvideos.csv")
data.head()
# Out:
#       video_id trending_date  \
# 0  5ugKfHgsmYw    2018-02-07
# 1  ohObafdd34Y    2018-02-07
# 2  aBr2kKAHN6M    2018-02-07
# 3  5wNnwChvmsQ    2018-02-07
# 4  B7J47qFvdsk    2018-02-07
#
#                                                title  \
# 0  é¸èªããªãåç´ã«è½ä¸ï¼è·¯ä¸ã®è»ã...
# 1  ã¤ããQ ãç¥­ãç·å®®å·Ãæè¶ å·¨å¤§ã...
# 2                              Live Views of Starman
# 3  æ±äº¬ãã£ãºãã¼ãªã¾ã¼ãã®å
# ã­ã£ã...
# 4  æ¦®åå¥ã
# ãè¡æã®æ­»ãã ãµãï¼æ ç...
#
#                     channel_title  category_id               publish_time  \
# 0  æäºéä¿¡æ åã»ã³ã¿ã¼           25  2018-02-06 03:04:37+00:00
# 1  ç¥è°·ãããª Kamiya Erina 2            1  2018-02-06 04:01:56+00:00
# 2                          SpaceX           28  2018-02-06 21:38:22+00:00
# 3           ã¢ã·ã¿ãã¯ãã¤           25  2018-02-06 06:08:49+00:00
# 4           ã·ãããã¥ãã¤            1  2018-02-06 02:30:00+00:00
#
#                                                 tags    views   likes  \
# 0  äºæ
# |"ä½è³"|"ä½è³ç"|"ããªã³ãã¿ã...   188085     591
# 1                                             [none]    90929     442
# 2                                             [none]  6408303  165892
# 3                              ã¢ã·ã¿ãã¯ãã¤    96255    1165
# 4                                             [none]   108408    1336
#
#    dislikes  comment_count         category_name  title_sentiment
# 0       189              0       News & Politics         0.000000
# 1        88            174      Film & Animation         0.000000
# 2      2331           3006  Science & Technology         0.136364
# 3       277            545       News & Politics         0.000000
# 4        74            201      Film & Animation         0.000000

# %%
plt.figure(figsize=(12,6))
sns.countplot(y='category_name', data=data, order = data['category_name'].value_counts().index)
plt.title('Most Trending Video Categories in JP')
plt.xlabel('Number of Videos')
plt.ylabel('Category')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(data['views'], bins=50, kde=True)
plt.title('Distribution of Video Views')
plt.xlabel('Views')
plt.ylabel('Frequency')
plt.show()
